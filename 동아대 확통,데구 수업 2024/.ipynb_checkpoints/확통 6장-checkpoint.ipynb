# %%
# 문재1
# H0: (S기업의 점심 비용 평균은 6,300원이다) μ=6300
# H1: (S기업의 점심 비용 평균은 6,300원이 아니다) 𝜇≠6300

import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats 
plt.rcParams['font.family'] ='D2coding'

data = pd.read_excel("C:/Users/darkr/OneDrive/Desktop/2학년1학기/확통/S기업_점심비용.xlsx")
mu=6300; n = 100
print(data.describe())

plt.hist(data, label='점심비용', bins=8)    
plt.legend(); plt.show()                                      

t = (np.mean(data) -mu) / (np.std(data, ddof=1) / np.sqrt(n))
print('t값=',t)
p = 1 -stats.t.cdf(t, n-1)
print('p값=',p)

result = stats.ttest_1samp(data.lunch, mu, alternative='greater')
print(result)

if p<0.05 : print('H0기각')
else : print('H0를기각할수없음')
# Out:
#              lunch
# count   100.000000
# mean   6434.000000
# std    1101.167425
# min    4300.000000
# 25%    5700.000000
# 50%    6350.000000
# 75%    7025.000000
# max    9200.000000
# t값= lunch    1.21689
# dtype: float64
# p값= [0.11326949]
# TtestResult(statistic=1.2168903384547618, pvalue=0.11326948593440751, df=99)
# H0를기각할수없음

# %%
# 문제2
# H0: (파이썬 과목을 수강하는 대학생의 주당 스마트폰 이용 시간 평균은 35시간이다) μ=35
# H1: (파이썬 과목을 수강하는 대학생의 주당 스마트폰 이용 시간 평균은 35시간이 아니다) 𝜇≠35

import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats 
plt.rcParams['font.family'] ='D2coding'

data = pd.read_csv("C:/Users/darkr/OneDrive/Desktop/2학년1학기/확통/스마트폰_이용시간.csv")
mu=35; n = 40
print(data.describe())

plt.hist(data, label='이용시간', bins=7)    
plt.legend(); plt.show()                                      

t = (np.mean(data) -mu) / (np.std(data, ddof=1) / np.sqrt(n))
print('t값=',t)
p = 1 -stats.t.cdf(t, n-1)
print('p값=',p)

result = stats.ttest_1samp(data, mu, alternative='less')
print(result)

if p<0.05 : print('H0기각')
else : print('H0를기각할수없음')
# Out:
#               27
# count  39.000000
# mean   39.512821
# std     9.765330
# min    15.000000
# 25%    34.500000
# 50%    39.000000
# 75%    45.000000
# max    57.000000
# t값= 27    2.922746
# dtype: float64
# p값= [0.00287403]
# TtestResult(statistic=array([2.88598077]), pvalue=array([0.9967999]), df=array([38]))
# H0기각

# %%
# 문제3
# H0: (소프트웨어 학과 학생들의 월 평균 스마트폰 이용 요금은 68,000원 이하이다) μ≤68000
# H1: (소프트웨어 학과 학생들의 월 평균 스마트폰 이용 요금은 68,000원보다 더 많다) μ>68000

import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats 
plt.rcParams['font.family'] ='D2coding'

data = pd.read_csv("C:/Users/darkr/OneDrive/Desktop/2학년1학기/확통/스마트폰_이용요금.txt")
mu=68000; n = 80
print(data.describe())

plt.hist(data, label='이용요금', bins=8)    
plt.legend(); plt.show()                                      

t = (np.mean(data) -mu) / (np.std(data, ddof=1) / np.sqrt(n))
print('t값=',t)
p = 1 -stats.t.cdf(t, n-1)
print('p값=',p)

result = stats.ttest_1samp(data, mu, alternative='greater')
print(result)

if p<0.05 : print('H0기각')
else : print('H0를기각할수없음')
# Out:
#               66000
# count     79.000000
# mean   69139.240506
# std    10469.411094
# min    46000.000000
# 25%    62000.000000
# 50%    68000.000000
# 75%    76000.000000
# max    94000.000000
# t값= 66000    0.973281
# dtype: float64
# p값= [0.16669225]
# TtestResult(statistic=array([0.96717867]), pvalue=array([0.16822204]), df=array([78]))
# H0를기각할수없음
